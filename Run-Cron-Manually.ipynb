# %%
from apps.school import tasks

# %%
import logging
import sys

logging.basicConfig(format='%(asctime)s | %(levelname)s : %(message)s',
                     level=logging.DEBUG, stream=sys.stdout)

# %%
tasks.daily_process_student_progress_index()
# Out:
# 2017-06-13 13:49:10,409 | INFO : Processing student 1/1152: 'Jens van Berkum'...
# 2017-06-13 13:49:10,433 | INFO : Processing student 2/1152: 'Mick Barents'...
# 2017-06-13 13:49:10,457 | INFO : Processing student 3/1152: 'Senna van Santen'...
# 2017-06-13 13:49:10,480 | INFO : Processing student 4/1152: 'Pien Maas'...
# 2017-06-13 13:49:10,503 | INFO : Processing student 5/1152: 'Sofia Kleibrink'...
# 2017-06-13 13:49:10,527 | INFO : Processing student 6/1152: 'Aylin Hendrikse'...
# 2017-06-13 13:49:10,550 | INFO : Processing student 7/1152: 'Kevin Suijker'...
# 2017-06-13 13:49:10,572 | INFO : Processing student 8/1152: 'Loes Verheij'...
# 2017-06-13 13:49:10,593 | INFO : Processing student 9/1152: 'Niels Brandon'...
# 2017-06-13 13:49:10,615 | INFO : Processing student 10/1152: 'Niels Kuit'...
# 2017-06-13 13:49:10,637 | INFO : Processing student 11/1152: 'Yusuf van de Water'...
# 2017-06-13 13:49:10,660 | INFO : Processing student 12/1152: 'Fabiënne Tins'...
# ...
